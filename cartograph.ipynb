# %%
import geopandas as gpd
file  = gpd.read_file("SECC_CPV_E_20111101_01_R_INE.shp")

# %%
import matplotlib as plt
# %matplotlib inline

# %%
file.head()
# Out:
#    OBJECTID       CUSEC  CUMUN CSEC CDIS CMUN CPRO CCA    CUDIS OBS  \
# 0         1  0100101001  01001  001   01  001   01  16  0100101
# 1         2  0100101002  01001  002   01  001   01  16  0100101
# 2         3  0100201001  01002  001   01  002   01  16  0100201
# 3         4  0100201002  01002  002   01  002   01  16  0100201
# 4         5  0100201003  01002  003   01  002   01  16  0100201
#
#                          ...                         CNUT2 CNUT3  CLAU2  \
# 0                        ...                             1     1  01001
# 1                        ...                             1     1  01001
# 2                        ...                             1     1  01002
# 3                        ...                             1     1  01002
# 4                        ...                             1     1  01002
#
#           NPRO         NCA              NMUN    Shape_Leng    Shape_area  \
# ...

# %%
list(file)
# Out:
# ['OBJECTID',
#  'CUSEC',
#  'CUMUN',
#  'CSEC',
#  'CDIS',
#  'CMUN',
#  'CPRO',
#  'CCA',
#  'CUDIS',
#  'OBS',
#  'CNUT0',
#  'CNUT1',
#  'CNUT2',
#  'CNUT3',
#  'CLAU2',
#  'NPRO',
#  'NCA',
#  'NMUN',
#  'Shape_Leng',
#  'Shape_area',
#  'Shape_len',
#  'geometry']

# %%
file['geometry'].plot()

# %%
madrid=file[(file['CPRO']=='28') & (file['CMUN']=='079')]

# %%
madrid
# Out:
#        OBJECTID       CUSEC  CUMUN CSEC CDIS CMUN CPRO CCA    CUDIS OBS  \
# 17693     17694  2807901001  28079  001   01  079   28  13  2807901
# 17694     17695  2807901002  28079  002   01  079   28  13  2807901
# 17695     17696  2807901003  28079  003   01  079   28  13  2807901
# 17696     17697  2807901004  28079  004   01  079   28  13  2807901
# 17697     17698  2807901006  28079  006   01  079   28  13  2807901
# 17698     17699  2807901007  28079  007   01  079   28  13  2807901
# 17699     17700  2807901008  28079  008   01  079   28  13  2807901
# 17700     17701  2807901009  28079  009   01  079   28  13  2807901
# 17701     17702  2807901011  28079  011   01  079   28  13  2807901
# 17702     17703  2807901012  28079  012   01  079   28  13  2807901
# 17703     17704  2807901013  28079  013   01  079   28  13  2807901
# 17704     17705  2807901014  28079  014   01  079   28  13  2807901
# 17705     17706  2807901015  28079  015   01  079   28  13  2807901
# ...

# %%
len(madrid)
# Out:
# 2409

# %%
madrid['geometry'].plot()
